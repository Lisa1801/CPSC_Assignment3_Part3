# %% [markdown]
# ## Exercise

# %% [markdown]
# For this exercise, you will be working with the [House Price Dataset](https://www.kaggle.com/competitions/house-prices-advanced-regression-techniques/code).
#
# Please grab the train.csv file from Kaggle and explore this dataset. You need to perform explroatory data analysis and see if there is any correlation between the variables and analyze the distribution of the dataset. The question is open-ended and basically you're asked to perform EDA.

# %% [markdown]
# 1- Write a summary of your findings in one page (e.g., summary statistics, plots) and submit the pdf file. Therefore, for part 3 of your assignment, you need to submit at least one jupyter notebook file and one pdf file.
#
#
# 2- Push your code and project to github and provide the link to your code here. Ensure that your github project is organized to at least couple of main folders, ensure that you have the README file as well:
#
# - Src
# - Data
# - Docs
# - Results
#
# Read this link for further info:  https://gist.github.com/ericmjl/27e50331f24db3e8f957d1fe7bbbe510

# %%
#1)

# %%
import numpy as np
import pandas as pd
import  matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("train.csv")

# %%
df.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
mean_price = df['SalePrice'].mean()
std_price = df['SalePrice'].std()

print("Mean Sale Price: ", mean_price)
print("Standard Deviation of Sale Price: ", std_price)
# Out:
# Mean Sale Price:  180921.19589041095
# Standard Deviation of Sale Price:  79442.50288288663

# %%
df.isnull().sum()
# Out:
# Id                 0
# MSSubClass         0
# MSZoning           0
# LotFrontage      259
# LotArea            0
#                 ...
# MoSold             0
# YrSold             0
# SaleType           0
# SaleCondition      0
# SalePrice          0
# Length: 81, dtype: int64

# %%
corr_matrix = df.corr()
sns.heatmap(corr_matrix, cmap='coolwarm', annot=False)
plt.show()

# %%
#Graph for the main variable "Sale Price"

plt.hist(df['SalePrice'])
plt.xlabel('Sale Price')
plt.ylabel('Frequency')
plt.show()

# %%
#Hypothesis1
#Sale price versus Lotarea
sale_price = df.groupby('LotArea')['SalePrice'].mean()
plt.scatter(sale_price.index, sale_price.values)
plt.xlabel('Lot Size')
plt.ylabel('Sale Price')
plt.show()

# %%
#From above graph it is clear that the variables have a postive relation. And mostly houses are sold upto the lot size 50000.

# %%
#Hypothesis2
#Sale price versus neighborhood



sale_price= df.groupby('Neighborhood')['SalePrice'].mean()
plt.scatter(sale_price.index, sale_price.values)
plt.xlabel('Neighborhood')
plt.ylabel('Sale Price')
plt.show()

# %% [markdown]
# By this graph it is clearly seen that there is no correlation between both the variables and the selling of houses does not
# depend on the neighborhood.

# %%
#Hypotheis 3
#Sale price versus Overall Quality

sale_price= df.groupby('OverallQual')['SalePrice'].mean()
plt.bar(sale_price.index, sale_price.values)
plt.xlabel('OverallQual')
plt.ylabel('SalePrice')
plt.show()

# %% [markdown]
# It clearly shows the relation is positive and the sale price depends on the overall quality of houses.
